# %%
import random
import math

# %%
def mutate(a_list):
    b_list = []
    new_item = 0
    for item in a_list:
        new_item = item * 2
        new_item += random.randint(a, b)
        new_item = math.add(new_item, item)
    b_list.append(new_item)
    print(b_list)

# %%
mutate(1, 2, 14, 17, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mutate(1, 2, 14, 17, 20)
#
# TypeError: mutate() takes 1 positional argument but 5 were given
